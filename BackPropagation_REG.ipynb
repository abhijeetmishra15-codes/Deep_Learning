# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8 , 8 , 4] , [7 , 9 , 5] , [5 , 12 , 7] , [6 , 10 , 6]], columns=['cgpa' , 'res_score' , 'lpa'])

# %%
df
# Out:
#    cgpa  res_score  lpa
# 0     8          8    4
# 1     7          9    5
# 2     5         12    7
# 3     6         10    6

# %%
def initialize_parameters(layer_dims):

  np.random.seed(3)
  parameters = {}
  L = len(layer_dims)

  for l in range(1 , L):
    parameters['W' + str(l)] = np.ones((layer_dims[l-1] , layer_dims[l])) * 0.1
    parameters['b' + str(l)] = np.zeros((layer_dims[l] , 1))

  return parameters

# %%
initialize_parameters([2 , 2, 1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev , W , b):

  Z = np.dot(W.T , A_prev) + b
  return Z

# %%
#Forward Propagation
def L_layer_forward(X , parameters):

  A = X
  L = len(parameters) // 2
  for l in range(1 , L+1):
    A_prev = A
    W1 = parameters['W' + str(l)]
    b1 = parameters['b' + str(l)]

    # print("A" + str(l-1)+ ": " , A_prev)
    # print("W" + str(l)+ ": " , W1)
    # print("b" + str(l)+ ": " , b1)
    # print("--"*20)

    A = linear_forward(A_prev , W1 , b1)
    # print("A"+str(l)+": " , A)
    # print("**"*20)

  return A , A_prev

# %%
X = df[['cgpa' , 'res_score']].values[0].reshape(2 , 1)
y = df[['lpa']].values[0][0]

parameters = initialize_parameters([2 , 2, 1])

y_hat , A1 = L_layer_forward(X , parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************

# %%
loss = (y - 0.32) ** 2
loss
# Out:
# np.float64(13.5424)

# %%
y_hat
# Out:
# np.float64(0.32000000000000006)

# %%
def update_parameters(parameters , y , y_hat , A1 , X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat) * A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat) * A1[1][0])
  parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat) * parameters['W2'][0][0] * X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat) * parameters['W2'][0][0] * X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat) * parameters['W2'][0][0])

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat) * parameters['W2'][1][0] * X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat) * parameters['W2'][1][0] * X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat) * parameters['W2'][1][0])

  return parameters

# %%
update_parameters(parameters , y , y_hat , A1 , X)
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
parameters = initialize_parameters([2 , 2, 1])
epochs = 75

for i in range(epochs):

  loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa' , 'res_score']].values[j].reshape(2 , 1)
    y = df[['lpa']].values[j][0]

    y_hat , A1 = L_layer_forward(X , parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters , y , y_hat , A1 , X)

    loss_ = (y - y_hat) ** 2
    loss.append(loss_)

  print('Epoch - ',i+1,'Loss - ',np.array(loss).mean())

parameters
# Out:
# Epoch -  1 Loss -  25.302541015384726
# Epoch -  2 Loss -  18.308728586218738
# Epoch -  3 Loss -  9.510715407674606
# Epoch -  4 Loss -  3.329550090243517
# Epoch -  5 Loss -  1.3937107926220875
# Epoch -  6 Loss -  1.1898627591856838
# Epoch -  7 Loss -  1.2322804391751778
# Epoch -  8 Loss -  1.261151518873883
# Epoch -  9 Loss -  1.272244947738656
# Epoch -  10 Loss -  1.2761926208831529
# Epoch -  11 Loss -  1.2777465916749513
# Epoch -  12 Loss -  1.2785540938937354
# Epoch -  13 Loss -  1.279148829745167
# Epoch -  14 Loss -  1.279699667366474
# Epoch -  15 Loss -  1.2802593513437437
# Epoch -  16 Loss -  1.280844100664364
# Epoch -  17 Loss -  1.2814587245589943
# Epoch -  18 Loss -  1.282104487956583
# Epoch -  19 Loss -  1.2827815606659365
# Epoch -  20 Loss -  1.2834897759367303
# Epoch -  21 Loss -  1.2842288641207933
# Epoch -  22 Loss -  1.284998524231225
# Epoch -  23 Loss -  1.2857984457092249
# Epoch -  24 Loss -  1.2866283149731312
# Epoch -  25 Loss -  1.2874878173312359
# Epoch -  26 Loss -  1.2883766374770043
# Epoch -  27 Loss -  1.2892944595395384
# Epoch -  28 Loss -  1.2902409669814487
# Epoch -  29 Loss -  1.291215842431552
# Epoch -  30 Loss -  1.2922187674784547
# Epoch -  31 Loss -  1.2932494224331132
# Epoch -  32 Loss -  1.2943074860629535
# Epoch -  33 Loss -  1.295392635298744
# Epoch -  34 Loss -  1.2965045449148496
# Epoch -  35 Loss -  1.2976428871834398
# Epoch -  36 Loss -  1.2988073315031745
# Epoch -  37 Loss -  1.2999975440028624
# Epoch -  38 Loss -  1.3012131871205528
# Epoch -  39 Loss -  1.3024539191585998
# Epoch -  40 Loss -  1.303719393815094
# Epoch -  41 Loss -  1.3050092596921457
# Epoch -  42 Loss -  1.3063231597814349
# Epoch -  43 Loss -  1.3076607309274115
# Epoch -  44 Loss -  1.3090216032685722
# Epoch -  45 Loss -  1.3104053996571017
# Epoch -  46 Loss -  1.311811735057301
# Epoch -  47 Loss -  1.3132402159230239
# Epoch -  48 Loss -  1.3146904395544878
# Epoch -  49 Loss -  1.3161619934346702
# Epoch -  50 Loss -  1.3176544545455842
# Epoch -  51 Loss -  1.319167388664623
# Epoch -  52 Loss -  1.3207003496412302
# Epoch -  53 Loss -  1.322252878654054
# Epoch -  54 Loss -  1.323824503448813
# Epoch -  55 Loss -  1.3254147375570402
# Epoch -  56 Loss -  1.3270230794958944
# Epoch -  57 Loss -  1.3286490119492218
# Epoch -  58 Loss -  1.330292000930041
# Epoch -  59 Loss -  1.3319514949246714
# Epoch -  60 Loss -  1.3336269240187144
# Epoch -  61 Loss -  1.3353176990050917
# Epoch -  62 Loss -  1.337023210474451
# Epoch -  63 Loss -  1.3387428278881794
# Epoch -  64 Loss -  1.3404758986343834
# Epoch -  65 Loss -  1.3422217470672129
# Epoch -  66 Loss -  1.3439796735299168
# Epoch -  67 Loss -  1.3457489533621803
# Epoch -  68 Loss -  1.3475288358922308
# Epoch -  69 Loss -  1.3493185434143813
# Epoch -  70 Loss -  1.3511172701527017
# Epoch -  71 Loss -  1.3529241812116428
# Epoch -  72 Loss -  1.3547384115144847
# Epoch -  73 Loss -  1.3565590647306374
# Epoch -  74 Loss -  1.3583852121929565
# Epoch -  75 Loss -  1.360215891806283
# {'W1': array([[-0.04264665,  0.69031959],
#         [-0.04785496,  0.82509822]]),
#  'b1': array([[0.02224061],
#         [0.0292282 ]]),
#  'W2': array([[0.3661003 ],
#         [0.45755239]]),
#  'b2': array([[0.45795754]])}

# %%
import tensorflow
from tensorflow import keras

from tensorflow.keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2 , activation='linear' , input_dim=2))
model.add(Dense(1 , activation='linear'))
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 0.16469288, -0.7957844 ],
#         [ 0.07655096, -0.8718641 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-1.2471017],
#         [ 0.9626235]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
new_weights = [np.array([[0.1 , 0.1] , [0.1 , 0.1]] , dtype=np.float32),
               np.array([0. , 0.] , dtype=np.float32),
               np.array([[0.1] , [0.1]] , dtype=np.float32),
               np.array([0.] , dtype=np.float32)]

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss = 'mean_squared_error' , optimizer = optimizer)

# %%
model.fit(df.iloc[: , 0:-1].values , df['lpa'].values , epochs = 75 , verbose=1 , batch_size=1)
# Out:
# Epoch 1/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83.8066
# Epoch 2/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 81.5672
# Epoch 3/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 79.3599
# Epoch 4/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 77.1918
# Epoch 5/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 75.0618
# Epoch 6/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 73.0676
# Epoch 7/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 70.9503
# Epoch 8/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 68.8841
# Epoch 9/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 66.9652
# Epoch 10/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 65.0233
# Epoch 11/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 63.0343
# Epoch 12/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 61.3073
# Epoch 13/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 59.4129
# Epoch 14/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 57.6722
# Epoch 15/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 55.8594
# Epoch 16/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 54.1475
# Epoch 17/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 52.5654
# Epoch 18/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 50.9736
# Epoch 19/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 49.2565
# Epoch 20/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.7736
# Epoch 21/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 46.2831
# Epoch 22/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 44.7413
# Epoch 23/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 43.2366
# Epoch 24/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.9275
# Epoch 25/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.5594
# Epoch 26/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.1751
# Epoch 27/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 37.8560
# Epoch 28/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 36.5046
# Epoch 29/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.3601
# Epoch 30/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 34.1735
# Epoch 31/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 32.8839
# Epoch 32/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.7752
# Epoch 33/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.7038
# Epoch 34/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.6259
# Epoch 35/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 28.5905
# Epoch 36/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.5111
# Epoch 37/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.4618
# Epoch 38/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.5588
# Epoch 39/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.6019
# Epoch 40/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.7278
# Epoch 41/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.8264
# Epoch 42/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.9534
# Epoch 43/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.1434
# Epoch 44/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.2833
# Epoch 45/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.5243
# Epoch 46/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.7568
# Epoch 47/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.0891
# Epoch 48/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.3464
# Epoch 49/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.7052
# Epoch 50/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.9816
# Epoch 51/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.4101
# Epoch 52/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.7251
# Epoch 53/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.1755
# Epoch 54/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.5599
# Epoch 55/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.0421
# Epoch 56/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.5041
# Epoch 57/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.9840
# Epoch 58/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.4462
# Epoch 59/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.0245
# Epoch 60/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.5726
# Epoch 61/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.1213
# Epoch 62/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6756
# Epoch 63/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.2286
# Epoch 64/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8500
# Epoch 65/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4984
# Epoch 66/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1445
# Epoch 67/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8123
# Epoch 68/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4467
# Epoch 69/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.1645
# Epoch 70/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.8163
# Epoch 71/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.5029
# Epoch 72/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.2642
# Epoch 73/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.9837
# Epoch 74/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.7299
# Epoch 75/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4799

# %%
model.get_weights()
# Out:
# [array([[-0.23150937, -0.46193582],
#         [-0.31696418, -0.5405441 ]], dtype=float32),
#  array([-0.4000201,  0.3369116], dtype=float32),
#  array([[-1.6182698 ],
#         [ 0.63703114]], dtype=float32),
#  array([0.37717792], dtype=float32)]
